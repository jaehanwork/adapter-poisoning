# %%
import os
import json
from dotenv import load_dotenv
import numpy as np

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case2_sentiment_moeBaseline')

file_list = [d for d in os.listdir(dir_path) if not d.startswith('.')]
file_list = sorted(file_list, key=lambda x: int(x.split('_')[2].lstrip('sample')))

for d in file_list:
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    try:
        with open(result_path, 'r') as f:
            _result = json.load(f)
    except:
        continue

    print(task_name)
    accuracy_list = []
    gate_acc_list = []
    gate_acc_topk_list = []
    gate_avg_gate_score_list = []
    for dataset, result in _result.items():
        accuracy = result['eval_accuracy']
        gate_acc = result['eval_gate_accuracy']
        gate_acc_topk = result['eval_gate_accuracy_topk']
        freq = result['eval_gate_freq_avg']
        gate_avg_gate_score = result['eval_gate_avg_gate_score']

        accuracy_list.append(accuracy)
        gate_acc_list.append(gate_acc)
        gate_acc_topk_list.append(gate_acc_topk)
        gate_avg_gate_score_list.append(gate_avg_gate_score)
        
        print(f'Dataset: {dataset}')
        print(f'accuracy: {accuracy}')
        print(f'gate_acc: {gate_acc}')
        print(f'gate_acc_topk: {gate_acc_topk}')
        print(f'gate freq: {freq}')
        print(f'gate avg gate_score: {gate_avg_gate_score}')
        print()
    print(f'avg accuracy: {np.mean(accuracy_list)}')
    print(f'avg gate accuracy: {np.mean(gate_acc_list)}')
    print(f'avg gate accuracy topk: {np.mean(gate_acc_topk_list)}')
    print('==========================================')
    print()
# Out:
# gating_sentiment_sample1250_20231129-164332
# Dataset: imdb
# accuracy: 0.9058399796485901
# gate_acc: 0.18264
# gate_acc_topk: 0.97608
# gate freq: [0.9761, 0.0324, 0.007, 0.9845]
# gate avg gate_score: [0.4797, 0.0158, 0.0036, 0.501]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9146341681480408
# gate_acc: 0.10318949343339587
# gate_acc_topk: 0.99906191369606
# gate freq: [0.0122, 0.9991, 0.9662, 0.0225]
# gate avg gate_score: [0.0058, 0.4356, 0.5474, 0.0112]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 0.9311926605504587
# gate_acc_topk: 0.981651376146789
# gate freq: [0.0046, 0.9977, 0.9817, 0.0161]
# gate avg gate_score: [0.0022, 0.4246, 0.5652, 0.0079]
#
# Dataset: yelp_polarity
# accuracy: 0.9586052894592285
# gate_acc: 0.8375526315789473
# gate_acc_topk: 0.881421052631579
# gate freq: [0.7322, 0.2186, 0.1677, 0.8814]
# gate avg gate_score: [0.3489, 0.1004, 0.0911, 0.4595]
#
# avg accuracy: 0.9315817803144455
# avg gate accuracy: 0.5136436963907005
# avg gate accuracy topk: 0.959553585618607
# ==========================================
#
# gating_sentiment_sample6250_20231129-165147
# Dataset: imdb
# accuracy: 0.9145200252532959
# gate_acc: 0.96912
# gate_acc_topk: 0.99036
# gate freq: [0.9904, 0.019, 0.001, 0.9897]
# gate avg gate_score: [0.5515, 0.0097, 0.0004, 0.4383]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9071294665336609
# gate_acc: 0.7945590994371482
# gate_acc_topk: 0.99906191369606
# gate freq: [0.0666, 0.9991, 0.8762, 0.0582]
# gate avg gate_score: [0.0265, 0.5664, 0.3887, 0.0184]
#
# Dataset: sst2
# accuracy: 0.9483944773674011
# gate_acc: 0.2580275229357798
# gate_acc_topk: 0.9254587155963303
# gate freq: [0.0367, 0.9966, 0.9255, 0.0413]
# gate avg gate_score: [0.0143, 0.536, 0.4362, 0.0135]
#
# Dataset: yelp_polarity
# accuracy: 0.9600789546966553
# gate_acc: 0.5843157894736842
# gate_acc_topk: 0.9368684210526316
# gate freq: [0.7817, 0.2127, 0.0687, 0.9369]
# gate avg gate_score: [0.38, 0.1087, 0.0362, 0.4751]
#
# avg accuracy: 0.9325307309627533
# avg gate accuracy: 0.651505602961653
# avg gate accuracy topk: 0.9629372625862554
# ==========================================
#
# gating_sentiment_sample12500_20231129-172503
# Dataset: imdb
# accuracy: 0.9155600070953369
# gate_acc: 0.9664
# gate_acc_topk: 0.99384
# gate freq: [0.9938, 0.0185, 0.001, 0.9866]
# gate avg gate_score: [0.5764, 0.0091, 0.0004, 0.4141]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9090056419372559
# gate_acc: 0.8142589118198874
# gate_acc_topk: 0.99812382739212
# gate freq: [0.0675, 0.9981, 0.8902, 0.0441]
# gate avg gate_score: [0.023, 0.6016, 0.3636, 0.0117]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 0.24770642201834864
# gate_acc_topk: 0.9323394495412844
# gate freq: [0.0287, 0.9943, 0.9323, 0.0447]
# gate avg gate_score: [0.0096, 0.558, 0.4195, 0.0129]
#
# Dataset: yelp_polarity
# accuracy: 0.9607895016670227
# gate_acc: 0.8119473684210526
# gate_acc_topk: 0.9558157894736842
# gate freq: [0.7941, 0.1916, 0.0586, 0.9558]
# gate avg gate_score: [0.3514, 0.0972, 0.0316, 0.5199]
#
# avg accuracy: 0.9331507086753845
# avg gate accuracy: 0.7100781755648222
# avg gate accuracy topk: 0.9700297666017721
# ==========================================
#
# gating_sentiment_sample25000_20231129-182815
# Dataset: imdb
# accuracy: 0.9171599745750427
# gate_acc: 0.98164
# gate_acc_topk: 0.99592
# gate freq: [0.9959, 0.0211, 0.0044, 0.9785]
# gate avg gate_score: [0.6739, 0.008, 0.0013, 0.3168]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9108818173408508
# gate_acc: 0.797373358348968
# gate_acc_topk: 0.99906191369606
# gate freq: [0.0863, 0.9991, 0.8977, 0.0169]
# gate avg gate_score: [0.0277, 0.6119, 0.3567, 0.0037]
#
# Dataset: sst2
# accuracy: 0.9461008906364441
# gate_acc: 0.3130733944954128
# gate_acc_topk: 0.944954128440367
# gate freq: [0.0482, 0.9874, 0.945, 0.0195]
# gate avg gate_score: [0.0164, 0.5435, 0.4369, 0.0032]
#
# Dataset: yelp_polarity
# accuracy: 0.9619473814964294
# gate_acc: 0.7878421052631579
# gate_acc_topk: 0.975421052631579
# gate freq: [0.8138, 0.1482, 0.0625, 0.9754]
# gate avg gate_score: [0.3485, 0.0662, 0.0343, 0.551]
#
# avg accuracy: 0.9340225160121918
# avg gate accuracy: 0.7199822145268846
# avg gate accuracy topk: 0.9788392736920015
# ==========================================
#
# gating_sentiment_sample62500_20231129-203154
# Dataset: imdb
# accuracy: 0.9159600138664246
# gate_acc: 0.97788
# gate_acc_topk: 0.99612
# gate freq: [0.9961, 0.0181, 0.0252, 0.9606]
# gate avg gate_score: [0.7154, 0.0066, 0.0051, 0.2729]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9090056419372559
# gate_acc: 0.7729831144465291
# gate_acc_topk: 0.99906191369606
# gate freq: [0.0779, 0.9991, 0.9174, 0.0056]
# gate avg gate_score: [0.0237, 0.6251, 0.3503, 0.001]
#
# Dataset: sst2
# accuracy: 0.9438073635101318
# gate_acc: 0.3486238532110092
# gate_acc_topk: 0.9541284403669725
# gate freq: [0.0459, 0.9954, 0.9541, 0.0046]
# gate avg gate_score: [0.0154, 0.5333, 0.4511, 0.0003]
#
# Dataset: yelp_polarity
# accuracy: 0.9625789523124695
# gate_acc: 0.8651842105263158
# gate_acc_topk: 0.9785789473684211
# gate freq: [0.8129, 0.1489, 0.0597, 0.9786]
# gate avg gate_score: [0.2936, 0.0575, 0.0322, 0.6167]
#
# avg accuracy: 0.9328379929065704
# avg gate accuracy: 0.7411677945459635
# avg gate accuracy topk: 0.9819723253578635
# ==========================================
#
# gating_sentiment_sample125000_20231129-233501
# Dataset: imdb
# accuracy: 0.9139999747276306
# gate_acc: 0.9778
# gate_acc_topk: 0.9968
# gate freq: [0.9968, 0.0649, 0.0086, 0.9297]
# gate avg gate_score: [0.8147, 0.0089, 0.001, 0.1754]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9071294665336609
# gate_acc: 0.7889305816135085
# gate_acc_topk: 0.9971857410881801
# gate freq: [0.0816, 0.9972, 0.909, 0.0122]
# gate avg gate_score: [0.017, 0.6825, 0.2986, 0.002]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 0.4105504587155963
# gate_acc_topk: 0.9518348623853211
# gate freq: [0.0459, 0.9874, 0.9518, 0.0149]
# gate avg gate_score: [0.011, 0.5259, 0.4607, 0.0025]
#
# Dataset: yelp_polarity
# accuracy: 0.9649210572242737
# gate_acc: 0.9436315789473684
# gate_acc_topk: 0.991
# gate freq: [0.8079, 0.1268, 0.0743, 0.991]
# gate avg gate_score: [0.1781, 0.0269, 0.027, 0.768]
#
# avg accuracy: 0.933324545621872
# avg gate accuracy: 0.7802281548191183
# avg gate accuracy topk: 0.9842051508683753
# ==========================================
