# %%
import os
import json
from dotenv import load_dotenv
import numpy as np

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case2_sentiment_moeBaseline')

file_list = [d for d in os.listdir(dir_path) if not d.startswith('.')]
file_list = sorted(file_list, key=lambda x: int(x.split('_')[2].lstrip('sample')))

for d in file_list:
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    try:
        with open(result_path, 'r') as f:
            _result = json.load(f)
    except:
        continue

    print(task_name)
    accuracy_list = []
    gate_acc_list = []
    gate_acc_topk_list = []
    for dataset, result in _result.items():
        accuracy = result['eval_accuracy']
        gate_acc = result['eval_gate_accuracy']
        gate_acc_topk = result['eval_gate_accuracy_topk']
        freq = result['eval_gate_freq_avg']

        accuracy_list.append(accuracy)
        gate_acc_list.append(gate_acc)
        gate_acc_topk_list.append(gate_acc_topk)
        
        print(f'Dataset: {dataset}')
        print(f'accuracy: {accuracy}')
        print(f'gate_acc: {gate_acc}')
        print(f'gate_acc_topk: {gate_acc_topk}')
        print(f'gate freq: {freq}')
        print()
    print(f'avg accuracy: {np.mean(accuracy_list)}')
    print(f'avg gate accuracy: {np.mean(gate_acc_list)}')
    print(f'avg gate accuracy topk: {np.mean(gate_acc_topk_list)}')
    print('==========================================')
    print()
# Out:
# gating_sentiment_sample1250_20231125-193918
# Dataset: imdb
# accuracy: 0.9102399945259094
# gate_acc: 0.90852
# gate_acc_topk: 0.9328
# gate freq: [0.9085, 0.0018, 0.0623, 0.0274]
#
# Dataset: rotten_tomatoes
# accuracy: 0.909943699836731
# gate_acc: 0.0009380863039399625
# gate_acc_topk: 1.0
# gate freq: [0.0, 0.0009, 0.9991, 0.0]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 1.0
# gate_acc_topk: 1.0
# gate freq: [0.0, 0.0, 1.0, 0.0]
#
# Dataset: yelp_polarity
# accuracy: 0.9531052708625793
# gate_acc: 0.1358421052631579
# gate_acc_topk: 0.6507368421052632
# gate freq: [0.5123, 0.0048, 0.3471, 0.1358]
#
# avg accuracy: 0.9301341623067856
# avg gate accuracy: 0.5113250478917745
# avg gate accuracy topk: 0.8958842105263157
# ==========================================
#
# gating_sentiment_sample6250_20231125-194414
# Dataset: imdb
# accuracy: 0.9122800230979919
# gate_acc: 0.97444
# gate_acc_topk: 0.99316
# gate freq: [0.9744, 0.0152, 0.0003, 0.0101]
#
# Dataset: rotten_tomatoes
# accuracy: 0.9090056419372559
# gate_acc: 0.7429643527204502
# gate_acc_topk: 0.99812382739212
# gate freq: [0.0, 0.743, 0.2561, 0.0009]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 0.34174311926605505
# gate_acc_topk: 0.9392201834862385
# gate freq: [0.0, 0.6583, 0.3417, 0.0]
#
# Dataset: yelp_polarity
# accuracy: 0.9625526070594788
# gate_acc: 0.8192894736842106
# gate_acc_topk: 0.9146315789473685
# gate freq: [0.0212, 0.1266, 0.033, 0.8193]
#
# avg accuracy: 0.9327714890241623
# avg gate accuracy: 0.7196092364176789
# avg gate accuracy topk: 0.9612838974564317
# ==========================================
#
# gating_sentiment_sample12500_20231125-201652
# Dataset: imdb
# accuracy: 0.9123200178146362
# gate_acc: 0.97632
# gate_acc_topk: 0.99792
# gate freq: [0.9763, 0.0126, 0.0002, 0.0108]
#
# Dataset: rotten_tomatoes
# accuracy: 0.906191349029541
# gate_acc: 0.7776735459662288
# gate_acc_topk: 0.9971857410881801
# gate freq: [0.0, 0.7777, 0.2214, 0.0009]
#
# Dataset: sst2
# accuracy: 0.9472476840019226
# gate_acc: 0.3130733944954128
# gate_acc_topk: 0.9472477064220184
# gate freq: [0.0, 0.6869, 0.3131, 0.0]
#
# Dataset: yelp_polarity
# accuracy: 0.9623947143554688
# gate_acc: 0.8009473684210526
# gate_acc_topk: 0.8767631578947368
# gate freq: [0.0083, 0.1625, 0.0283, 0.8009]
#
# avg accuracy: 0.9320384413003922
# avg gate accuracy: 0.7170035772206735
# avg gate accuracy topk: 0.9547791513512338
# ==========================================
#
# gating_sentiment_sample25000_20231125-211606
# Dataset: imdb
# accuracy: 0.9119600057601929
# gate_acc: 0.97396
# gate_acc_topk: 0.9956
# gate freq: [0.974, 0.0082, 0.0002, 0.0177]
#
# Dataset: rotten_tomatoes
# accuracy: 0.903377115726471
# gate_acc: 0.8095684803001876
# gate_acc_topk: 0.9962476547842402
# gate freq: [0.0, 0.8096, 0.1895, 0.0009]
#
# Dataset: sst2
# accuracy: 0.9461008906364441
# gate_acc: 0.31422018348623854
# gate_acc_topk: 0.9243119266055045
# gate freq: [0.0, 0.6846, 0.3142, 0.0011]
#
# Dataset: yelp_polarity
# accuracy: 0.9641315937042236
# gate_acc: 0.9049473684210526
# gate_acc_topk: 0.9519473684210527
# gate freq: [0.0037, 0.0627, 0.0287, 0.9049]
#
# avg accuracy: 0.9313924014568329
# avg gate accuracy: 0.7506740080518697
# avg gate accuracy topk: 0.9670267374526993
# ==========================================
