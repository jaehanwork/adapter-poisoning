# %%
import logging
import os
import random
import sys
from dataclasses import dataclass, field
from typing import Optional
import json

import datasets
import numpy as np
from datasets import load_dataset

import evaluate
import transformers
from transformers import (
    AutoConfig,
    AutoTokenizer,
    DataCollatorWithPadding,
    EvalPrediction,
    HfArgumentParser,
    PretrainedConfig,
    Trainer,
    TrainingArguments,
    default_data_collator,
    set_seed,
)
from transformers.adapters import AdapterArguments, AdapterTrainer, AdapterConfigBase, AutoAdapterModel, setup_adapter_training
from transformers import BertTokenizer, BertModelWithHeads, AdapterConfig, EvalPrediction, TextClassificationPipeline
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version
from transformers.utils.versions import require_version

transformers.logging.set_verbosity_error()

from torch.utils.data import DataLoader, TensorDataset
import torch

from pdb import set_trace
import transformers.adapters.composition as ac
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

task_to_keys = {
    "cola": ("sentence", None),
    "mnli": ("premise", "hypothesis"),
    "mrpc": ("sentence1", "sentence2"),
    "qnli": ("question", "sentence"),
    "qqp": ("question1", "question2"),
    "rte": ("sentence1", "sentence2"),
    "sst2": ("sentence", None),
    "stsb": ("sentence1", "sentence2"),
    "wnli": ("sentence1", "sentence2"),

    'rotten_tomatoes': ("text", None),
    'imdb': ("text", None),
    'yelp_polarity': ("text", None),
    
}

adapter_info = {'cola': {'load_adapter': 'lingaccept/cola@ukp', 'adapter_config': 'pfeiffer'},
                # 'mnli'
                'mrpc': {'load_adapter': 'sts/mrpc@ukp',        'adapter_config': 'pfeiffer'},
                'qnli': {'load_adapter': 'nli/qnli@ukp',        'adapter_config': 'pfeiffer'},
                'qqp' : {'load_adapter': 'sts/qqp@ukp',         'adapter_config': 'pfeiffer'},
                'rte' : {'load_adapter': 'nli/rte@ukp',         'adapter_config': 'pfeiffer'},
                'sst2': {'load_adapter': 'sentiment/sst-2@ukp', 'adapter_config': 'pfeiffer'},
                'stsb': {'load_adapter': 'sts/sts-b@ukp',       'adapter_config': 'pfeiffer'},
                
                'rotten_tomatoes': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-rotten_tomatoes', 'adapter_config': 'pfeiffer'},
                'imdb': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-imdb', 'adapter_config': 'pfeiffer'},
                'yelp_polarity': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-yelp_polarity', 'adapter_config': 'pfeiffer'},
               }

eval_data_dict = {'imdb': 'test', 'yelp_polarity': 'test'}

is_glue = {"cola": True,
            "mnli": True,
            "mrpc": True,
            "qnli": True,
             "qqp": True,
             "rte": True,
            "sst2": True,
            "stsb": True,
            "wnli": True,}

metric_dict = {'rotten_tomatoes': 'sst2', 'imdb': 'sst2', 'yelp_polarity': 'sst2'}

data_dir = './data_ign/'
trial_dir = 'parallel_attack_stealthy_mergeLoss_residual_v1'

# %%
epoch = 3

model_name_or_path = 'bert-base-uncased'
pad_to_max_length = True
max_seq_length = 128
output_dir = os.path.join(data_dir, f'evaluate_parallel_loadAdapter/{trial_dir}')

BATCH_SIZE = 128
set_seed(0)

tokenizer = AutoTokenizer.from_pretrained(
    model_name_or_path,
)

# %%
def get_attacker_path(attacker_name, full_name=None):
    trial_path = os.path.join(data_dir, trial_dir)
    for model_dir in os.listdir(trial_path):
        if full_name:
            if full_name == model_dir:
                return os.path.join(trial_path, model_dir)
        else:
            if attacker_name in model_dir:
                return os.path.join(trial_path, model_dir)
                
def get_epoch_path(attacker_path, attacker_name, epoch=None):
    if epoch == None:
        return os.path.join(attacker_path, f'trained_adapters/{attacker_name}')
    else:
        checkpoint_name_dict = {}
        for dir_name in sorted(os.listdir(attacker_path)):
            if dir_name.startswith('checkpoint'):
                checkpoint_name_dict[dir_name] = int(dir_name.split('-')[-1])
        checkpoint_epoch = sorted(checkpoint_name_dict.items(), key=lambda x: x[1])[epoch-1][0]
        return os.path.join(attacker_path, f'{checkpoint_epoch}/trained_adapters/{attacker_name}')

# %%
def get_num_labels(task_name, raw_datasets):
    # Labels
    if task_name is not None:
        is_regression = task_name == "stsb"
        if not is_regression:
            label_list = raw_datasets["train"].features["label"].names
            num_labels = len(label_list)
        else:
            num_labels = 1
    else:
        # Trying to have good defaults here, don't hesitate to tweak to your needs.
        is_regression = raw_datasets["train"].features["label"].dtype in ["float32", "float64"]
        if is_regression:
            num_labels = 1
        else:
            # A useful fast method:
            # https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.unique
            label_list = raw_datasets["train"].unique("label")
            label_list.sort()  # Let's sort it for determinism
            num_labels = len(label_list)
    return num_labels, is_regression

def get_data(task_name, raw_datasets):
    sentence1_key, sentence2_key = task_to_keys[task_name]

    if pad_to_max_length:
        padding = "max_length"

    def preprocess_function(examples):    
        # Tokenize the texts
        args = (
            (examples[sentence1_key],) if sentence2_key is None else (examples[sentence1_key], examples[sentence2_key])
        )
        result = tokenizer(*args, padding=padding, max_length=max_seq_length, truncation=True)
    
        # Map labels to IDs (not necessary for GLUE tasks)
        # if label_to_id is not None and "label" in examples:
            # result["label"] = [(label_to_id[l] if l != -1 else -1) for l in examples["label"]]
        result["label"] = [(l if l != -1 else -1) for l in examples["label"]]
        return result
    
    raw_datasets = raw_datasets.map(
        preprocess_function,
        batched=True,
        desc="Running tokenizer on dataset",
    )

    return raw_datasets

def get_compute_metrics(task_name, is_regression):
    if task_name in metric_dict:
        metric = evaluate.load("glue", metric_dict[task_name])
    else:
        metric = evaluate.load("glue", task_name)
    
    def compute_metrics(p: EvalPrediction):
        preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
        preds = np.squeeze(preds) if is_regression else np.argmax(preds, axis=1)
        if task_name is not None:
            result = metric.compute(predictions=preds, references=p.label_ids)
            if len(result) > 1:
                result["combined_score"] = np.mean(list(result.values())).item()
            return result
        elif is_regression:
            return {"mse": ((preds - p.label_ids) ** 2).mean().item()}
        else:
            return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}

    return compute_metrics

def do_round(metric_dict):
    result = {}
    for k, v in metric_dict.items():
        result[k] = round(v, 4)
    return result

# %%
tasks = ["cola", "mrpc", "qnli", "qqp", "rte", "sst2", "stsb"]

attacker_adapter_list = []
for attacker in tasks:
    for victim in tasks:
        if attacker == victim:
            continue

        attacker_name = f'{attacker}_attack_{victim}'
        attacker_path = get_attacker_path(attacker_name, None)
        attacker_adapter = get_epoch_path(attacker_path, attacker_name, epoch)

        print(f'{attacker}: {attacker_adapter}')
        attacker_adapter_list.append({'attacker_task': attacker, 'attacker_name': attacker_name, 'attacker_adapter': attacker_adapter})
# Out:
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_mrpc_20231101-032237/checkpoint-201/trained_adapters/cola_attack_mrpc
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_qnli_20231101-110633/checkpoint-2457/trained_adapters/cola_attack_qnli
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_qqp_20231101-174849/checkpoint-8529/trained_adapters/cola_attack_qqp
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_rte_20231102-104731/checkpoint-201/trained_adapters/cola_attack_rte
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_sst2_20231102-150221/checkpoint-1581/trained_adapters/cola_attack_sst2
# cola: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/cola_attack_stsb_20231102-203452/checkpoint-201/trained_adapters/cola_attack_stsb
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_cola_20231031-230334/checkpoint-201/trained_adapters/mrpc_attack_cola
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_qnli_20231101-115305/checkpoint-2457/trained_adapters/mrpc_attack_qnli
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_qqp_20231101-203822/checkpoint-8529/trained_adapters/mrpc_attack_qqp
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_rte_20231102-105153/checkpoint-87/trained_adapters/mrpc_attack_rte
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_sst2_20231102-153059/checkpoint-1581/trained_adapters/mrpc_attack_sst2
# mrpc: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/mrpc_attack_stsb_20231102-203928/checkpoint-135/trained_adapters/mrpc_attack_stsb
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_cola_20231031-230755/checkpoint-2457/trained_adapters/qnli_attack_cola
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_mrpc_20231101-032659/checkpoint-2457/trained_adapters/qnli_attack_mrpc
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_qqp_20231101-232812/checkpoint-8529/trained_adapters/qnli_attack_qqp
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_rte_20231102-105357/checkpoint-2457/trained_adapters/qnli_attack_rte
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_sst2_20231102-155954/checkpoint-2457/trained_adapters/qnli_attack_sst2
# qnli: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qnli_attack_stsb_20231102-204254/checkpoint-2457/trained_adapters/qnli_attack_stsb
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_cola_20231031-235422/checkpoint-8529/trained_adapters/qqp_attack_cola
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_mrpc_20231101-041328/checkpoint-8529/trained_adapters/qqp_attack_mrpc
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_qnli_20231101-123931/checkpoint-8529/trained_adapters/qqp_attack_qnli
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_rte_20231102-114023/checkpoint-8529/trained_adapters/qqp_attack_rte
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_sst2_20231102-164634/checkpoint-8529/trained_adapters/qqp_attack_sst2
# qqp: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/qqp_attack_stsb_20231102-212919/checkpoint-8529/trained_adapters/qqp_attack_stsb
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_cola_20231101-024437/checkpoint-201/trained_adapters/rte_attack_cola
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_mrpc_20231101-070334/checkpoint-174/trained_adapters/rte_attack_mrpc
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_qnli_20231101-152929/checkpoint-2457/trained_adapters/rte_attack_qnli
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_qqp_20231102-021840/checkpoint-8529/trained_adapters/rte_attack_qqp
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_sst2_20231102-193655/checkpoint-1581/trained_adapters/rte_attack_sst2
# rte: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/rte_attack_stsb_20231103-001846/checkpoint-135/trained_adapters/rte_attack_stsb
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_cola_20231101-024906/checkpoint-1581/trained_adapters/sst2_attack_cola
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_mrpc_20231101-103424/checkpoint-1581/trained_adapters/sst2_attack_mrpc
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_qnli_20231101-161554/checkpoint-2457/trained_adapters/sst2_attack_qnli
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_qqp_20231102-050839/checkpoint-8529/trained_adapters/sst2_attack_qqp
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_rte_20231102-143007/checkpoint-1581/trained_adapters/sst2_attack_rte
# sst2: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/sst2_attack_stsb_20231103-002210/checkpoint-1581/trained_adapters/sst2_attack_stsb
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_cola_20231101-031801/checkpoint-201/trained_adapters/stsb_attack_cola
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_mrpc_20231101-110308/checkpoint-135/trained_adapters/stsb_attack_mrpc
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_qnli_20231101-170215/checkpoint-2457/trained_adapters/stsb_attack_qnli
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_qqp_20231102-075753/checkpoint-8529/trained_adapters/stsb_attack_qqp
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_rte_20231102-145856/checkpoint-135/trained_adapters/stsb_attack_rte
# stsb: ./data_ign/parallel_attack_stealthy_mergeLoss_residual_v1/stsb_attack_sst2_20231102-200550/checkpoint-1581/trained_adapters/stsb_attack_sst2

# %%
dataset_dict = {}
for task in tqdm(tasks):
    raw_datasets = load_dataset("glue", task) if task in is_glue else load_dataset(task)
    num_labels, is_regression = get_num_labels(task, raw_datasets)
    dataset = get_data(task, raw_datasets)
    
    eval_dataset = dataset[eval_data_dict[task]] if task in eval_data_dict else dataset['validation']
    compute_metrics = get_compute_metrics(task, is_regression)

    dataset_dict[task] = {'eval_dataset': eval_dataset, 'compute_metrics': compute_metrics}
# Out:
# 100%|██████████| 7/7 [00:23<00:00,  3.32s/it]

# %%
result = {}
for attacker_adapter_dict in attacker_adapter_list:
    attacker_task = attacker_adapter_dict['attacker_task']
    attacker_name = attacker_adapter_dict['attacker_name']
    attacker_adapter = attacker_adapter_dict['attacker_adapter']

    result[attacker_name] = {}
    
    for task in tasks:
        if attacker_task == task:
            continue

        task_name_1 = task
        task_name_2 = attacker_task

        load_adapter_1 = adapter_info[task_name_1]['load_adapter']
        adapter_config_1 = AdapterConfigBase.load(adapter_info[task_name_1]['adapter_config'])

        eval_dataset_1 = dataset_dict[task_name_1]['eval_dataset']
        eval_dataset_2 = dataset_dict[task_name_2]['eval_dataset']

        compute_metrics_1 = dataset_dict[task_name_1]['compute_metrics']
        compute_metrics_2 = dataset_dict[task_name_2]['compute_metrics']

        # We use the AutoAdapterModel class here for better adapter support.
        model = AutoAdapterModel.from_pretrained(
            model_name_or_path,
            ignore_mismatched_sizes=False
        )
        
        adapter1 = model.load_adapter(load_adapter_1)
        adapter2 = model.load_adapter(attacker_adapter)
        
        model.active_adapters = ac.Parallel(adapter1, attacker_name)


        # Convert data to tensors and move to device
        input_ids = torch.tensor(eval_dataset_1['input_ids'])
        token_type_ids = torch.tensor(eval_dataset_1['token_type_ids'])
        attention_mask = torch.tensor(eval_dataset_1['attention_mask'])
        labels = torch.tensor(eval_dataset_1['label'])
        
        # Create a DataLoader
        dataset = TensorDataset(input_ids, token_type_ids, attention_mask, labels)
        dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
        
        model = model.to(device)
        model.eval()
        
        all_logits = []
        all_labels = []
        
        with torch.no_grad():
            for batch in dataloader:
                batch = [b_input.to(device) for b_input in batch]
                b_input_ids, b_token_type_ids, b_attention_mask, b_labels = batch
                inputs = {
                    'input_ids': b_input_ids,
                    'token_type_ids': b_token_type_ids,
                    'attention_mask': b_attention_mask
                }
                
                output1, output2 = model(**inputs)
                logits = output1.logits
                all_logits.append(logits.cpu().numpy())
                all_labels.append(b_labels.cpu().numpy())
        
        # Get predictions
        prediction1 = np.concatenate(all_logits, axis=0)
        all_labels = np.concatenate(all_labels, axis=0)
        
        # Evaluate
        compute_results = compute_metrics_1(EvalPrediction(predictions=prediction1, label_ids=all_labels))
        # print(do_round(compute_results))
        
        result1 = compute_results

        # Convert data to tensors and move to device
        input_ids = torch.tensor(eval_dataset_2['input_ids'])
        token_type_ids = torch.tensor(eval_dataset_2['token_type_ids'])
        attention_mask = torch.tensor(eval_dataset_2['attention_mask'])
        labels = torch.tensor(eval_dataset_2['label'])
        
        # Create a DataLoader
        dataset = TensorDataset(input_ids, token_type_ids, attention_mask, labels)
        dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)
        
        all_logits = []
        all_labels = []
        
        with torch.no_grad():
            for batch in dataloader:
                batch = [b_input.to(device) for b_input in batch]
                b_input_ids, b_token_type_ids, b_attention_mask, b_labels = batch
                inputs = {
                    'input_ids': b_input_ids,
                    'token_type_ids': b_token_type_ids,
                    'attention_mask': b_attention_mask
                }
                
                output1, output2 = model(**inputs)
                logits = output2.logits
                all_logits.append(logits.cpu().numpy())
                all_labels.append(b_labels.cpu().numpy())
        
        # Get predictions
        prediction1 = np.concatenate(all_logits, axis=0)
        all_labels = np.concatenate(all_labels, axis=0)
        
        # Evaluate
        compute_results = compute_metrics_2(EvalPrediction(predictions=prediction1, label_ids=all_labels))
        # print(do_round(compute_results))
        
        result2 = compute_results

        result[attacker_name][task_name_1] = {'victim_task': result1, 'attacker_task': result2}

        os.makedirs(output_dir, exist_ok=True)

        result_path = os.path.join(output_dir, f'{attacker_name}.json')
        with open(result_path, 'w') as f:
            json.dump(result, f)

        result1_round = do_round(result1)
        result2_round = do_round(result2)
        
        print(f'{attacker_name} {task_name_1} {result1_round} {result2_round}')
# Out:
# cola_attack_mrpc mrpc {'accuracy': 0.6887, 'f1': 0.8146, 'combined_score': 0.7517} {'matthews_correlation': 0.4891}
# cola_attack_mrpc qnli {'accuracy': 0.7959} {'matthews_correlation': 0.3944}
# cola_attack_mrpc qqp {'accuracy': 0.7933, 'f1': 0.7777, 'combined_score': 0.7855} {'matthews_correlation': 0.2257}
# cola_attack_mrpc rte {'accuracy': 0.574} {'matthews_correlation': 0.3636}
# cola_attack_mrpc sst2 {'accuracy': 0.8188} {'matthews_correlation': 0.3633}
# cola_attack_mrpc stsb {'pearson': 0.7803, 'spearmanr': 0.854, 'combined_score': 0.8172} {'matthews_correlation': 0.4558}
# cola_attack_qnli mrpc {'accuracy': 0.6838, 'f1': 0.8122, 'combined_score': 0.748} {'matthews_correlation': 0.5792}
# cola_attack_qnli qnli {'accuracy': 0.495} {'matthews_correlation': 0.5687}
# cola_attack_qnli qqp {'accuracy': 0.4704, 'f1': 0.5817, 'combined_score': 0.526} {'matthews_correlation': 0.3321}
# cola_attack_qnli rte {'accuracy': 0.5271} {'matthews_correlation': 0.5235}
# cola_attack_qnli sst2 {'accuracy': 0.7856} {'matthews_correlation': 0.527}
# cola_attack_qnli stsb {'pearson': 0.3152, 'spearmanr': 0.4074, 'combined_score': 0.3613} {'matthews_correlation': 0.5048}
# cola_attack_qqp mrpc {'accuracy': 0.6838, 'f1': 0.8122, 'combined_score': 0.748} {'matthews_correlation': 0.5433}
# cola_attack_qqp qnli {'accuracy': 0.4948} {'matthews_correlation': 0.5339}
# cola_attack_qqp qqp {'accuracy': 0.3683, 'f1': 0.5382, 'combined_score': 0.4533} {'matthews_correlation': 0.5645}
# cola_attack_qqp rte {'accuracy': 0.5271} {'matthews_correlation': 0.5354}
# cola_attack_qqp sst2 {'accuracy': 0.6617} {'matthews_correlation': 0.5599}
# cola_attack_qqp stsb {'pearson': 0.3032, 'spearmanr': 0.3021, 'combined_score': 0.3026} {'matthews_correlation': 0.4991}
# cola_attack_rte mrpc {'accuracy': 0.6936, 'f1': 0.817, 'combined_score': 0.7553} {'matthews_correlation': 0.499}
# cola_attack_rte qnli {'accuracy': 0.8014} {'matthews_correlation': 0.5}
# cola_attack_rte qqp {'accuracy': 0.7926, 'f1': 0.777, 'combined_score': 0.7848} {'matthews_correlation': 0.1252}
# cola_attack_rte rte {'accuracy': 0.5668} {'matthews_correlation': 0.5129}
# cola_attack_rte sst2 {'accuracy': 0.8704} {'matthews_correlation': 0.3411}
# cola_attack_rte stsb {'pearson': 0.8051, 'spearmanr': 0.8542, 'combined_score': 0.8296} {'matthews_correlation': 0.4856}
# cola_attack_sst2 mrpc {'accuracy': 0.6912, 'f1': 0.8158, 'combined_score': 0.7535} {'matthews_correlation': 0.5261}
# cola_attack_sst2 qnli {'accuracy': 0.7578} {'matthews_correlation': 0.5496}
# cola_attack_sst2 qqp {'accuracy': 0.7736, 'f1': 0.7597, 'combined_score': 0.7666} {'matthews_correlation': 0.4792}
# cola_attack_sst2 rte {'accuracy': 0.5776} {'matthews_correlation': 0.551}
# cola_attack_sst2 sst2 {'accuracy': 0.5115} {'matthews_correlation': 0.5715}
# cola_attack_sst2 stsb {'pearson': 0.7195, 'spearmanr': 0.8107, 'combined_score': 0.7651} {'matthews_correlation': 0.5554}
# cola_attack_stsb mrpc {'accuracy': 0.6887, 'f1': 0.8146, 'combined_score': 0.7517} {'matthews_correlation': 0.5126}
# cola_attack_stsb qnli {'accuracy': 0.7783} {'matthews_correlation': 0.4063}
# cola_attack_stsb qqp {'accuracy': 0.7793, 'f1': 0.7666, 'combined_score': 0.773} {'matthews_correlation': 0.2307}
# cola_attack_stsb rte {'accuracy': 0.5668} {'matthews_correlation': 0.3891}
# cola_attack_stsb sst2 {'accuracy': 0.8188} {'matthews_correlation': 0.3865}
# cola_attack_stsb stsb {'pearson': 0.7253, 'spearmanr': 0.85, 'combined_score': 0.7877} {'matthews_correlation': 0.4637}
# mrpc_attack_cola cola {'matthews_correlation': 0.3686} {'accuracy': 0.7819, 'f1': 0.8524, 'combined_score': 0.8171}
# mrpc_attack_cola qnli {'accuracy': 0.7099} {'accuracy': 0.6593, 'f1': 0.6904, 'combined_score': 0.6749}
# mrpc_attack_cola qqp {'accuracy': 0.812, 'f1': 0.6915, 'combined_score': 0.7518} {'accuracy': 0.4093, 'f1': 0.2397, 'combined_score': 0.3245}
# mrpc_attack_cola rte {'accuracy': 0.5235} {'accuracy': 0.6446, 'f1': 0.6667, 'combined_score': 0.6556}
# mrpc_attack_cola sst2 {'accuracy': 0.8509} {'accuracy': 0.7672, 'f1': 0.8435, 'combined_score': 0.8053}
# mrpc_attack_cola stsb {'pearson': 0.7941, 'spearmanr': 0.8141, 'combined_score': 0.8041} {'accuracy': 0.7279, 'f1': 0.7692, 'combined_score': 0.7486}
# mrpc_attack_qnli cola {'matthews_correlation': 0.3736} {'accuracy': 0.7794, 'f1': 0.858, 'combined_score': 0.8187}
# mrpc_attack_qnli qnli {'accuracy': 0.5058} {'accuracy': 0.875, 'f1': 0.9119, 'combined_score': 0.8935}
# mrpc_attack_qnli qqp {'accuracy': 0.7863, 'f1': 0.6311, 'combined_score': 0.7087} {'accuracy': 0.5441, 'f1': 0.5053, 'combined_score': 0.5247}
# mrpc_attack_qnli rte {'accuracy': 0.5343} {'accuracy': 0.7794, 'f1': 0.8308, 'combined_score': 0.8051}
# mrpc_attack_qnli sst2 {'accuracy': 0.8222} {'accuracy': 0.7672, 'f1': 0.849, 'combined_score': 0.8081}
# mrpc_attack_qnli stsb {'pearson': 0.7664, 'spearmanr': 0.766, 'combined_score': 0.7662} {'accuracy': 0.8431, 'f1': 0.8889, 'combined_score': 0.866}
# mrpc_attack_qqp cola {'matthews_correlation': 0.3264} {'accuracy': 0.7304, 'f1': 0.8348, 'combined_score': 0.7826}
# mrpc_attack_qqp qnli {'accuracy': 0.6081} {'accuracy': 0.8186, 'f1': 0.8791, 'combined_score': 0.8489}
# mrpc_attack_qqp qqp {'accuracy': 0.3683, 'f1': 0.5383, 'combined_score': 0.4533} {'accuracy': 0.8799, 'f1': 0.9145, 'combined_score': 0.8972}
# mrpc_attack_qqp rte {'accuracy': 0.5162} {'accuracy': 0.8333, 'f1': 0.8859, 'combined_score': 0.8596}
# mrpc_attack_qqp sst2 {'accuracy': 0.6823} {'accuracy': 0.7353, 'f1': 0.8378, 'combined_score': 0.7866}
# mrpc_attack_qqp stsb {'pearson': 0.6379, 'spearmanr': 0.6894, 'combined_score': 0.6636} {'accuracy': 0.7966, 'f1': 0.8689, 'combined_score': 0.8327}
# mrpc_attack_rte cola {'matthews_correlation': 0.4943} {'accuracy': 0.7059, 'f1': 0.823, 'combined_score': 0.7644}
# mrpc_attack_rte qnli {'accuracy': 0.8479} {'accuracy': 0.7917, 'f1': 0.8576, 'combined_score': 0.8246}
# mrpc_attack_rte qqp {'accuracy': 0.8559, 'f1': 0.802, 'combined_score': 0.829} {'accuracy': 0.6471, 'f1': 0.6771, 'combined_score': 0.6621}
# mrpc_attack_rte rte {'accuracy': 0.6498} {'accuracy': 0.777, 'f1': 0.8515, 'combined_score': 0.8143}
# mrpc_attack_rte sst2 {'accuracy': 0.906} {'accuracy': 0.7181, 'f1': 0.8286, 'combined_score': 0.7734}
# mrpc_attack_rte stsb {'pearson': 0.8484, 'spearmanr': 0.8486, 'combined_score': 0.8485} {'accuracy': 0.7819, 'f1': 0.859, 'combined_score': 0.8204}
# mrpc_attack_sst2 cola {'matthews_correlation': 0.0993} {'accuracy': 0.8186, 'f1': 0.8771, 'combined_score': 0.8479}
# mrpc_attack_sst2 qnli {'accuracy': 0.65} {'accuracy': 0.6127, 'f1': 0.6165, 'combined_score': 0.6146}
# mrpc_attack_sst2 qqp {'accuracy': 0.7581, 'f1': 0.5472, 'combined_score': 0.6527} {'accuracy': 0.3701, 'f1': 0.1462, 'combined_score': 0.2581}
# mrpc_attack_sst2 rte {'accuracy': 0.4874} {'accuracy': 0.5735, 'f1': 0.5584, 'combined_score': 0.566}
# mrpc_attack_sst2 sst2 {'accuracy': 0.4908} {'accuracy': 0.8358, 'f1': 0.8851, 'combined_score': 0.8604}
# mrpc_attack_sst2 stsb {'pearson': 0.7181, 'spearmanr': 0.7119, 'combined_score': 0.715} {'accuracy': 0.6593, 'f1': 0.6834, 'combined_score': 0.6713}
# mrpc_attack_stsb cola {'matthews_correlation': 0.4977} {'accuracy': 0.723, 'f1': 0.8311, 'combined_score': 0.7771}
# mrpc_attack_stsb qnli {'accuracy': 0.7871} {'accuracy': 0.777, 'f1': 0.8312, 'combined_score': 0.8041}
# mrpc_attack_stsb qqp {'accuracy': 0.8354, 'f1': 0.7497, 'combined_score': 0.7926} {'accuracy': 0.549, 'f1': 0.5233, 'combined_score': 0.5362}
# mrpc_attack_stsb rte {'accuracy': 0.5884} {'accuracy': 0.7426, 'f1': 0.8115, 'combined_score': 0.7771}
# mrpc_attack_stsb sst2 {'accuracy': 0.8888} {'accuracy': 0.7475, 'f1': 0.8427, 'combined_score': 0.7951}
# mrpc_attack_stsb stsb {'pearson': 0.8189, 'spearmanr': 0.8267, 'combined_score': 0.8228} {'accuracy': 0.799, 'f1': 0.8566, 'combined_score': 0.8278}
# qnli_attack_cola cola {'matthews_correlation': 0.0} {'accuracy': 0.9008}
# qnli_attack_cola mrpc {'accuracy': 0.5319, 'f1': 0.5165, 'combined_score': 0.5242} {'accuracy': 0.8704}
# qnli_attack_cola qqp {'accuracy': 0.7361, 'f1': 0.4788, 'combined_score': 0.6075} {'accuracy': 0.669}
# qnli_attack_cola rte {'accuracy': 0.4874} {'accuracy': 0.8191}
# qnli_attack_cola sst2 {'accuracy': 0.5183} {'accuracy': 0.8898}
# qnli_attack_cola stsb {'pearson': 0.7571, 'spearmanr': 0.7963, 'combined_score': 0.7767} {'accuracy': 0.8995}
# qnli_attack_mrpc cola {'matthews_correlation': 0.3393} {'accuracy': 0.8612}
# qnli_attack_mrpc mrpc {'accuracy': 0.6912, 'f1': 0.8158, 'combined_score': 0.7535} {'accuracy': 0.9028}
# qnli_attack_mrpc qqp {'accuracy': 0.8327, 'f1': 0.7874, 'combined_score': 0.81} {'accuracy': 0.7615}
# qnli_attack_mrpc rte {'accuracy': 0.5993} {'accuracy': 0.8651}
# qnli_attack_mrpc sst2 {'accuracy': 0.9071} {'accuracy': 0.8746}
# qnli_attack_mrpc stsb {'pearson': 0.8006, 'spearmanr': 0.8095, 'combined_score': 0.8051} {'accuracy': 0.8715}
# qnli_attack_qqp cola {'matthews_correlation': 0.2551} {'accuracy': 0.8224}
# qnli_attack_qqp mrpc {'accuracy': 0.7598, 'f1': 0.8506, 'combined_score': 0.8052} {'accuracy': 0.8744}
# qnli_attack_qqp qqp {'accuracy': 0.3684, 'f1': 0.5383, 'combined_score': 0.4533} {'accuracy': 0.9015}
# qnli_attack_qqp rte {'accuracy': 0.5632} {'accuracy': 0.8957}
# qnli_attack_qqp sst2 {'accuracy': 0.7752} {'accuracy': 0.8294}
# qnli_attack_qqp stsb {'pearson': 0.7761, 'spearmanr': 0.7827, 'combined_score': 0.7794} {'accuracy': 0.8349}
# qnli_attack_rte cola {'matthews_correlation': 0.4213} {'accuracy': 0.8252}
# qnli_attack_rte mrpc {'accuracy': 0.3824, 'f1': 0.2125, 'combined_score': 0.2974} {'accuracy': 0.888}
# qnli_attack_rte qqp {'accuracy': 0.7337, 'f1': 0.4905, 'combined_score': 0.6121} {'accuracy': 0.7781}
# qnli_attack_rte rte {'accuracy': 0.4765} {'accuracy': 0.9033}
# qnli_attack_rte sst2 {'accuracy': 0.9128} {'accuracy': 0.8303}
# qnli_attack_rte stsb {'pearson': 0.4354, 'spearmanr': 0.4126, 'combined_score': 0.424} {'accuracy': 0.8495}
# qnli_attack_sst2 cola {'matthews_correlation': 0.1242} {'accuracy': 0.8808}
# qnli_attack_sst2 mrpc {'accuracy': 0.5515, 'f1': 0.5481, 'combined_score': 0.5498} {'accuracy': 0.8821}
# qnli_attack_sst2 qqp {'accuracy': 0.7492, 'f1': 0.533, 'combined_score': 0.6411} {'accuracy': 0.7302}
# qnli_attack_sst2 rte {'accuracy': 0.491} {'accuracy': 0.8488}
# qnli_attack_sst2 sst2 {'accuracy': 0.4908} {'accuracy': 0.9023}
# qnli_attack_sst2 stsb {'pearson': 0.7189, 'spearmanr': 0.7311, 'combined_score': 0.725} {'accuracy': 0.9026}
# qnli_attack_stsb cola {'matthews_correlation': 0.2923} {'accuracy': 0.8755}
# qnli_attack_stsb mrpc {'accuracy': 0.3162, 'f1': 0.0, 'combined_score': 0.1581} {'accuracy': 0.8664}
# qnli_attack_stsb qqp {'accuracy': 0.6333, 'f1': 0.0117, 'combined_score': 0.3225} {'accuracy': 0.611}
# qnli_attack_stsb rte {'accuracy': 0.4729} {'accuracy': 0.8693}
# qnli_attack_stsb sst2 {'accuracy': 0.8979} {'accuracy': 0.8841}
# qnli_attack_stsb stsb {'pearson': -0.2936, 'spearmanr': -0.4903, 'combined_score': -0.392} {'accuracy': 0.8852}
# qqp_attack_cola cola {'matthews_correlation': 0.0} {'accuracy': 0.8981, 'f1': 0.8638, 'combined_score': 0.8809}
# qqp_attack_cola mrpc {'accuracy': 0.3652, 'f1': 0.1338, 'combined_score': 0.2495} {'accuracy': 0.8235, 'f1': 0.7032, 'combined_score': 0.7634}
# qqp_attack_cola qnli {'accuracy': 0.5338} {'accuracy': 0.8186, 'f1': 0.6942, 'combined_score': 0.7564}
