# %%
import os
import json
from dotenv import load_dotenv

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case1_sts_moeBaseline')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    if 'yelp' in task_name:
        continue

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(result['eval_metric']['accuracy'])
    print()
# Out:
# imdb_with_rotten_tomatoes_20231107-010821
# 0.8781200051307678
#
# imdb_with_sst2_20231107-014243
# 0.8801599740982056
#
# rotten_tomatoes_with_imdb_20231107-020436
# 0.8602251410484314
#
# rotten_tomatoes_with_sst2_20231107-021547
# 0.9071294665336609
#
# sst2_with_imdb_20231108-050201
# 0.9208715558052063
#
# sst2_with_rotten_tomatoes_20231108-052401
# 0.9300458431243896

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackTraining_v3')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('attackerOnly', result['eval_attackerOnly']['dataset_2']['eval_accuracy'])
    print('mix', result['eval_mix']['dataset_1']['eval_accuracy_mixed'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231115-210113
# attackerOnly 0.870639979839325
# mix 0.5
#
# imdb_attack_sst2_20231115-212933
# attackerOnly 0.8786399960517883
# mix 0.49082568287849426
#
# imdb_attack_yelp_polarity_20231115-221413
# attackerOnly 0.8711599707603455
# mix 0.5
#
# rotten_tomatoes_attack_imdb_20231115-225516
# attackerOnly 0.8517823815345764
# mix 0.5732799768447876
#
# rotten_tomatoes_attack_sst2_20231115-230948
# attackerOnly 0.8517823815345764
# mix 0.9002293348312378
#
# rotten_tomatoes_attack_sst2_20231117-110503
# attackerOnly 0.8517823815345764
# mix 0.9002293348312378
#
# rotten_tomatoes_attack_yelp_polarity_20231115-232228
# attackerOnly 0.8621013164520264
# mix 0.3677368462085724
#
# sst2_attack_imdb_20231115-233804
# attackerOnly 0.9128440618515015
# mix 0.5
#
# sst2_attack_rotten_tomatoes_20231116-013242
# attackerOnly 0.911697268486023
# mix 0.5
#
# sst2_attack_yelp_polarity_20231116-034247
# attackerOnly 0.9025229215621948
# mix 0.5
#
# yelp_polarity_attack_imdb_20231116-053821
# attackerOnly 0.9495000243186951
# mix 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231116-125923
# attackerOnly 0.944947361946106
# mix 0.5
#
# yelp_polarity_attack_sst2_20231116-203022
# attackerOnly 0.9463157653808594
# mix 0.49082568287849426

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackEvaluation_v2')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231114-213538
# Victim accuracy 0.5
#
# imdb_attack_sst2_20231114-213904
# Victim accuracy 0.5091742873191833
#
# imdb_attack_yelp_polarity_20231114-221548
# Victim accuracy 0.5539736747741699
#
# rotten_tomatoes_attack_imdb_20231115-011027
# Victim accuracy 0.871999979019165
#
# rotten_tomatoes_attack_sst2_20231115-013109
# Victim accuracy 0.9426605701446533
#
# rotten_tomatoes_attack_yelp_polarity_20231115-022352
# Victim accuracy 0.9480526447296143
#
# sst2_attack_imdb_20231115-093906
# Victim accuracy 0.5094000101089478
#
# sst2_attack_rotten_tomatoes_20231115-095148
# Victim accuracy 0.5694183707237244
#
# sst2_attack_yelp_polarity_20231115-095851
# Victim accuracy 0.9256842136383057
#
# yelp_polarity_attack_imdb_20231115-184831
# Victim accuracy 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231115-190114
# Victim accuracy 0.5
#
# yelp_polarity_attack_sst2_20231115-190429
# Victim accuracy 0.5091742873191833

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackEvaluation_v3')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231118-115920
# Victim accuracy 0.4953095614910126
#
# imdb_attack_sst2_20231118-120237
# Victim accuracy 0.5091742873191833
