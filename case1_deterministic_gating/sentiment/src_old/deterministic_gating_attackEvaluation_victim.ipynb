# %%
import logging
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
import random
import sys
from dataclasses import dataclass, field
from typing import Optional, List

import datasets
import numpy as np
from datasets import load_dataset, concatenate_datasets

from pprint import pprint

import evaluate
import transformers
from transformers import (
    AutoConfig,
    AutoTokenizer,
    DataCollatorWithPadding,
    EvalPrediction,
    HfArgumentParser,
    PretrainedConfig,
    Trainer,
    TrainingArguments,
    default_data_collator,
    set_seed,
    get_scheduler,
    PfeifferConfig
)
from transformers.adapters import AdapterArguments, AdapterTrainer, AdapterConfigBase, AutoAdapterModel, setup_adapter_training
from transformers import BertTokenizer, BertModelWithHeads, AdapterConfig, EvalPrediction, TextClassificationPipeline
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version
from transformers.utils.versions import require_version

from torch.utils.data import DataLoader
import torch

from pdb import set_trace
import transformers.adapters.composition as ac

from transformers.adapters.heads import ClassificationHead
from torch.nn import CrossEntropyLoss, MSELoss

from transformers.trainer_utils import EvalLoopOutput

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, recall_score

from tqdm import tqdm
import json
from datetime import datetime
import random
from datasets import concatenate_datasets

from transformers import EarlyStoppingCallback

import torch.nn as nn
import torch.nn.functional as F

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
device_count = torch.cuda.device_count()
print(device, device_count)

task_to_keys = {
    "cola": ("sentence", None),
    "mnli": ("premise", "hypothesis"),
    "mrpc": ("sentence1", "sentence2"),
    "qnli": ("question", "sentence"),
    "qqp": ("question1", "question2"),
    "rte": ("sentence1", "sentence2"),
    "sst2": ("sentence", None),
    "stsb": ("sentence1", "sentence2"),
    "wnli": ("sentence1", "sentence2"),

    'rotten_tomatoes': ("text", None),
    'imdb': ("text", None),
    'yelp_polarity': ("text", None),
    
}

adapter_info = {'cola': {'load_adapter': 'lingaccept/cola@ukp', 'adapter_config': 'pfeiffer'},
                # 'mnli'
                'mrpc': {'load_adapter': 'sts/mrpc@ukp',        'adapter_config': 'pfeiffer'},
                'qnli': {'load_adapter': 'nli/qnli@ukp',        'adapter_config': 'pfeiffer'},
                'qqp' : {'load_adapter': 'sts/qqp@ukp',         'adapter_config': 'pfeiffer'},
                'rte' : {'load_adapter': 'nli/rte@ukp',         'adapter_config': 'pfeiffer'},
                'sst2': {'load_adapter': 'sentiment/sst-2@ukp', 'adapter_config': 'pfeiffer'},
                'stsb': {'load_adapter': 'sts/sts-b@ukp',       'adapter_config': 'pfeiffer'},
                
                'rotten_tomatoes': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-rotten_tomatoes', 'adapter_config': 'pfeiffer'},
                'imdb': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-imdb', 'adapter_config': 'pfeiffer'},
                'yelp_polarity': {'load_adapter': 'AdapterHub/bert-base-uncased-pf-yelp_polarity', 'adapter_config': 'pfeiffer'},
               }

eval_data_dict = {'imdb': 'test', 'yelp_polarity': 'test'}

is_glue = {"cola": True,
            "mnli": True,
            "mrpc": True,
            "qnli": True,
             "qqp": True,
             "rte": True,
            "sst2": True,
            "stsb": True,
            "wnli": True,}

metric_dict = {'rotten_tomatoes': 'sst2', 'imdb': 'sst2', 'yelp_polarity': 'sst2'}

current_time = datetime.now().strftime('%Y%m%d-%H%M%S')

data_dir = './data_ign/'
# Out:
# cuda:1 1

# %%
task_name_1 = 'imdb'
task_name_2 = 'rotten_tomatoes'

task_name = f'{task_name_2}_attack_{task_name_1}'
model_name_or_path = 'bert-base-uncased'
pad_to_max_length = True
max_seq_length = 128
do_oversample = True
output_dir = os.path.join(data_dir, f'deterministic_gating_attackEvaluation_residual_victim_tmp/{task_name}_{current_time}')
load_adapter_1 = adapter_info[task_name_1]['load_adapter']
load_adapter_2 = adapter_info[task_name_2]['load_adapter']

adapter_config_1 = AdapterConfigBase.load(adapter_info[task_name_1]['adapter_config'])

trial = 'rotten_tomatoes_attack_imdb_20231108-160930'

attacker_adapter = f'./data_ign/deterministic_gating_attackTraining_residual_tmp/{trial}/trained_adapters/rotten_tomatoes_attack_imdb'

random_seed = 0

set_seed(random_seed)
torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)

print(output_dir)
# Out:
# ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418

# %%
raw_datasets = load_dataset("glue", adapter1) if task_name_1 in is_glue else load_dataset(task_name_1)

# %%
tokenizer = AutoTokenizer.from_pretrained(
    model_name_or_path,
)

def get_data(task_name, raw_datasets):
    sentence1_key, sentence2_key = task_to_keys[task_name]

    if pad_to_max_length:
        padding = "max_length"

    def preprocess_function(examples):    
        # Tokenize the texts
        args = (
            (examples[sentence1_key],) if sentence2_key is None else (examples[sentence1_key], examples[sentence2_key])
        )
        result = tokenizer(*args, padding=padding, max_length=max_seq_length, truncation=True)
    
        # Map labels to IDs (not necessary for GLUE tasks)
        # if label_to_id is not None and "label" in examples:
            # result["label"] = [(label_to_id[l] if l != -1 else -1) for l in examples["label"]]
        result["label"] = [(l if l != -1 else -1) for l in examples["label"]]
        return result
        
    raw_datasets = raw_datasets.map(
        preprocess_function,
        batched=True,
        desc="Running tokenizer on dataset",
    )

    return raw_datasets

# %%
def get_num_labels(task_name, raw_datasets):
    # Labels
    if task_name_1 is not None:
        is_regression = task_name == "stsb"
        if not is_regression:
            label_list = raw_datasets["train"].features["label"].names
            num_labels = len(label_list)
        else:
            num_labels = 1
    else:
        # Trying to have good defaults here, don't hesitate to tweak to your needs.
        is_regression = raw_datasets["train"].features["label"].dtype in ["float32", "float64"]
        if is_regression:
            num_labels = 1
        else:
            # A useful fast method:
            # https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.unique
            label_list = raw_datasets["train"].unique("label")
            label_list.sort()  # Let's sort it for determinism
            num_labels = len(label_list)
    return num_labels, is_regression

num_labels, is_regression = get_num_labels(task_name_2, raw_datasets)

# %%
dataset = get_data(task_name_2, raw_datasets)

train_dataset = dataset['train']

_train_dataset = dataset['train'].train_test_split(test_size=0.2, shuffle=True, seed=random_seed)

train_dataset = _train_dataset['train']
valid_dataset = _train_dataset['test']

eval_dataset = dataset['validation'] if task_name_1 not in eval_data_dict else dataset[eval_data_dict[task_name_1]]

# %%
model = AutoAdapterModel.from_pretrained(
    model_name_or_path,
    ignore_mismatched_sizes=False
)

model.freeze_model(True)

adapter1 = model.load_adapter(load_adapter_1, with_head=False, config=adapter_config_1)
adapter2 = model.load_adapter(attacker_adapter)

model.active_adapters = ac.Parallel(adapter1, adapter2)

model.add_classification_head(adapter1)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertAdapterModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
print(model.adapter_summary())
# Out:
# ================================================================================
# Name                     Architecture         #Param      %Param  Active   Train
# --------------------------------------------------------------------------------
# imdb                     bottleneck          894,528       0.817       1       1
# rotten_tomatoes_attack_imdbbottleneck          894,528       0.817       1       1
# --------------------------------------------------------------------------------
# Full model                               109,482,240     100.000               1
# ================================================================================

# %%
model.active_head
# Out:
# 'imdb'

# %%
for k, v in model.named_parameters():
    if 'heads' in k:
            pass
    else:
        v.requires_grad = False

# %%
for k, v in model.named_parameters():
    if v.requires_grad:
        print(k)
# Out:
# heads.imdb.1.weight
# heads.imdb.1.bias
# heads.imdb.4.weight
# heads.imdb.4.bias

# %%
per_device_train_batch_size = 32
per_device_eval_batch_size = 1024
weight_decay = 0.0
learning_rate = 1e-5
num_train_epochs = 20
lr_scheduler_type = 'cosine'
warmup_steps = 0.1
patience = 2

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
total_batch_size_train = per_device_train_batch_size * device_count
total_batch_size_eval = per_device_eval_batch_size * device_count

# %%
def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.argmax(preds, axis=1)
    
    return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}

# %%
training_args = TrainingArguments(
    report_to='all',
    remove_unused_columns=False,
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    num_train_epochs=num_train_epochs,
    logging_dir="./logs",
    seed=random_seed,
    data_seed=random_seed,
    do_train=True,
    do_eval=True,
    evaluation_strategy='epoch',
    logging_strategy='epoch',
    learning_rate=learning_rate,
    lr_scheduler_type=lr_scheduler_type,
    warmup_steps=warmup_steps,
    save_strategy='epoch',
    load_best_model_at_end = True,
    metric_for_best_model = 'loss'
)

loss_fct = CrossEntropyLoss()

class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs):
        labels = inputs.pop('labels')

        # Compute model outputs
        outputs = model(**inputs)

        logits = outputs[0].logits
        
        loss = loss_fct(logits.view(-1, num_labels), labels.view(-1))

        return loss
        
    def evaluation_loop(
        self,
        dataloader,
        description: str,
        prediction_loss_only: Optional[bool] = None,
        ignore_keys: Optional[List[str]] = None,
        metric_key_prefix: str = "eval",
    ):
        # This is a simple modification. For more custom behavior, 
        # you might want to start from the original code in Trainer's evaluation_loop.
        
        # Initialize metrics, etc.
        self.model.eval()
        total_eval_loss = 0
        total_preds = []
        total_logits = []
        total_labels = []
        total_eval_metrics = {}
        
        for step, inputs in enumerate(dataloader):
            labels = inputs.pop('labels').to(self.args.device)
            
            # Move inputs to appropriate device
            for k, v in inputs.items():
                inputs[k] = v.to(self.args.device)
            
            # Forward pass and compute loss and metrics
            with torch.no_grad():
                outputs = model(**inputs)

                logits = outputs[0].logits

            loss = loss_fct(logits.view(-1, num_labels), labels.view(-1))

            total_eval_loss += loss.item()

            total_logits.extend(logits.detach().cpu().numpy())
            total_preds.extend(logits.argmax(dim=-1))
            total_labels.extend(labels.detach().cpu().numpy())

        average_eval_loss = total_eval_loss / len(dataloader)
        
        eval_pred = EvalPrediction(predictions=total_logits, label_ids=total_labels)
        
        metrics = self.compute_metrics(eval_pred)

        # Average the metrics
        num_eval_samples = len(dataloader.dataset)
        total_eval_metrics = {f'{metric_key_prefix}_loss': average_eval_loss, f'{metric_key_prefix}_metric': metrics}

        # return total_eval_loss, total_eval_metrics
        return EvalLoopOutput(predictions=total_preds, 
                              label_ids=total_labels, 
                              metrics=total_eval_metrics, 
                              num_samples=num_eval_samples)


trainer = CustomTrainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=valid_dataset,
        tokenizer=tokenizer,
        data_collator=default_data_collator,
        compute_metrics=compute_metrics,
        callbacks = [EarlyStoppingCallback(early_stopping_patience=patience)]
    )

# %%
os.makedirs(output_dir, exist_ok=True)
train_result = trainer.train()
metrics = train_result.metrics

loss_history = {'oversample': do_oversample,
                'max_seq_length': max_seq_length,
                'random_seed': random_seed,
                'lr': learning_rate,
                'early_stopping_patience': patience,
                'total_batch_size': total_batch_size_train,
                'num_train_epoch': num_train_epochs}

with open(os.path.join(output_dir, "hyperparameters.json"), "w") as f:
    json.dump(loss_history, f)

trainer.save_model()

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()

os.makedirs(os.path.join(output_dir, f"trained_head"), exist_ok=True)
model.save_head(os.path.join(output_dir, f"trained_head/{task_name_1}"), task_name_1)
# Out:
# /home/jaehan/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 20000
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 12500
#   Number of trainable parameters = 592130
#     <div>
#
#       <progress value='12500' max='12500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12500/12500 17:37, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.681900</td>
#       <td>0.662652</td>
#       <td>{'accuracy': 0.6972000002861023}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.656700</td>
#       <td>0.634920</td>
#       <td>{'accuracy': 0.7210000157356262}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.635100</td>
#       <td>0.611736</td>
#       <td>{'accuracy': 0.7351999878883362}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.617500</td>
#       <td>0.593616</td>
#       <td>{'accuracy': 0.724399983882904}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.603200</td>
#       <td>0.575057</td>
#       <td>{'accuracy': 0.7436000108718872}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.590600</td>
#       <td>0.565314</td>
#       <td>{'accuracy': 0.7332000136375427}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.583400</td>
#       <td>0.551900</td>
#       <td>{'accuracy': 0.7516000270843506}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.575400</td>
#       <td>0.547075</td>
#       <td>{'accuracy': 0.7454000115394592}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.568400</td>
#       <td>0.540488</td>
#       <td>{'accuracy': 0.748199999332428}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.562900</td>
#       <td>0.532315</td>
#       <td>{'accuracy': 0.7573999762535095}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.564200</td>
#       <td>0.527814</td>
#       <td>{'accuracy': 0.7608000040054321}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.559800</td>
#       <td>0.526717</td>
#       <td>{'accuracy': 0.7585999965667725}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.559700</td>
#       <td>0.522022</td>
#       <td>{'accuracy': 0.76419997215271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.558100</td>
#       <td>0.520494</td>
#       <td>{'accuracy': 0.7656000256538391}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.554600</td>
#       <td>0.519001</td>
#       <td>{'accuracy': 0.7644000053405762}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.552300</td>
#       <td>0.517942</td>
#       <td>{'accuracy': 0.7681999802589417}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.553300</td>
#       <td>0.517609</td>
#       <td>{'accuracy': 0.7656000256538391}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.554200</td>
#       <td>0.517225</td>
#       <td>{'accuracy': 0.7662000060081482}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.554800</td>
#       <td>0.517213</td>
#       <td>{'accuracy': 0.7653999924659729}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.552600</td>
#       <td>0.517251</td>
#       <td>{'accuracy': 0.765999972820282}</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-625/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1250/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-1875/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-2500/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3125/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3750/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3750/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3750/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3750/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-3750/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-4375/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5000/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-5625/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6250/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-6875/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-7500/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8125/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-8750/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-9375/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10000/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-10625/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11250/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/trained_adapters/rotten_tomatoes_attack_imdb/adapter_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-12500/trained_adapters/rotten_tomatoes_attack_imdb/pytorch_adapter.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/checkpoint-11875 (score: 0.5172131419181824).
# Saving model checkpoint to ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/config.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/generation_config.json
# Model weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/pytorch_model.bin
# tokenizer config file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/tokenizer_config.json
# Special tokens file saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/special_tokens_map.json
# Configuration saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/trained_head/imdb/head_config.json
# Module weights saved in ./data_ign/deterministic_gating_attackEvaluation_residual_victim_tmp/rotten_tomatoes_attack_imdb_20231108-182418/trained_head/imdb/pytorch_model_head.bin
# ***** train metrics *****
#   epoch                    =       20.0
#   total_flos               = 25184949GF
#   train_loss               =     0.5819
#   train_runtime            = 0:17:37.82
#   train_samples_per_second =    378.134
#   train_steps_per_second   =     11.817

# %%
metrics = trainer.evaluate(eval_dataset=eval_dataset)
pprint(metrics)
trainer.save_metrics("eval", metrics)
# Out:
# {'epoch': 20.0,
#  'eval_loss': 0.5194656991958618,
#  'eval_metric': {'accuracy': 0.7634000182151794},
#  'eval_runtime': 45.4443,
#  'eval_samples_per_second': 550.124,
#  'eval_steps_per_second': 0.55}

# %%
input('Remove files?\n')
import shutil
directory_path = output_dir
shutil.rmtree(directory_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 input('Remove files?\n')
#       2 import shutil
#       3 directory_path = output_dir
#
# File ~/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/ipykernel/kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
