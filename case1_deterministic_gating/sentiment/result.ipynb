# %%
import os
import json
from dotenv import load_dotenv
import numpy as np

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_singleAdapter_inference')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_20231127-084612
# Victim accuracy 0.9095600247383118
#
# rotten_tomatoes_20231127-084712
# Victim accuracy 0.899624764919281
#
# sst2_20231127-084723
# Victim accuracy 0.9495412707328796
#
# yelp_polarity_20231127-084734
# Victim accuracy 0.9660526514053345

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_moeBaseline_v4')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(result['eval_accuracy'])
    print()
# Out:
# imdb_with_rotten_tomatoes_20231127-013437
# 0.9081599712371826
#
# imdb_with_sst2_20231127-015203
# 0.9059200286865234
#
# imdb_with_yelp_polarity_20231127-020339
# 0.916159987449646
#
# rotten_tomatoes_with_imdb_20231127-021253
# 0.8968105316162109
#
# rotten_tomatoes_with_sst2_20231127-021539
# 0.9146341681480408
#
# rotten_tomatoes_with_yelp_polarity_20231127-021914
# 0.9052532911300659
#
# sst2_with_imdb_20231127-022200
# 0.9369266033172607
#
# sst2_with_rotten_tomatoes_20231127-025022
# 0.9472476840019226
#
# sst2_with_yelp_polarity_20231127-033346
# 0.9323394298553467
#
# yelp_polarity_with_imdb_20231128-020519
# 0.9640263319015503
#
# yelp_polarity_with_rotten_tomatoes_20231128-073123
# 0.9634736776351929
#
# yelp_polarity_with_sst2_20231128-134321
# 0.9620526432991028

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_moeBaseline')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(np.around(result['eval_accuracy'], 4))
    print()
# Out:
# imdb_with_rotten_tomatoes_20231218-195109
# 0.9062
#
# imdb_with_sst2_20231218-195437
# 0.9043
#
# imdb_with_yelp_polarity_20231218-195805
# 0.9151
#
# rotten_tomatoes_with_imdb_20231218-200134
# 0.8987
#
# rotten_tomatoes_with_sst2_20231218-200222
# 0.9156
#
# rotten_tomatoes_with_yelp_polarity_20231218-200310
# 0.8959
#
# sst2_with_imdb_20231218-200357
# 0.9346
#
# sst2_with_rotten_tomatoes_20231218-201056
# 0.9472
#
# sst2_with_yelp_polarity_20231218-201756
# 0.93
#
# yelp_polarity_with_imdb_20231218-202457
# 0.9637

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_residualVictim_attackTraining_v4')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('attackerOnly', result['eval_attackerOnly']['dataset_2']['eval_accuracy'])
    print('mix', result['eval_mix']['dataset_1']['eval_accuracy_mixed'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231127-151000
# attackerOnly 0.9043200016021729
# mix 0.5
#
# imdb_attack_sst2_20231127-155459
# attackerOnly 0.9052000045776367
# mix 0.49082568287849426
#
# imdb_attack_yelp_polarity_20231128-214647
# attackerOnly 0.9063599705696106
# mix 0.5
#
# rotten_tomatoes_attack_imdb_20231127-163949
# attackerOnly 0.8742964267730713
# mix 0.8421599864959717
#
# rotten_tomatoes_attack_sst2_20231127-165514
# attackerOnly 0.8864915370941162
# mix 0.4931192696094513
#
# rotten_tomatoes_attack_yelp_polarity_20231128-223849
# attackerOnly 0.894934356212616
# mix 0.5001842379570007
#
# sst2_attack_imdb_20231127-171118
# attackerOnly 0.9415137767791748
# mix 0.5000799894332886
#
# sst2_attack_rotten_tomatoes_20231127-092729
# attackerOnly 0.9277523159980774
# mix 0.5
#
# sst2_attack_rotten_tomatoes_20231128-225739
# attackerOnly 0.9277523159980774
# mix 0.5
#
# sst2_attack_yelp_polarity_20231129-005936
# attackerOnly 0.9380733966827393
# mix 0.5
#
# yelp_polarity_attack_imdb_20231129-030319
# attackerOnly 0.961552619934082
# mix 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231130-043340
# attackerOnly 0.9580000042915344
# mix 0.5
#
# yelp_polarity_attack_sst2_20231130-143013
# attackerOnly 0.9619210362434387
# mix 0.5091742873191833

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_residualVictim_attackTraining')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('attackerOnly', result['eval_attackerOnly']['dataset_2']['eval_accuracy'])
    print('mix', result['eval_mix']['dataset_1']['eval_accuracy_mixed'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231219-024253
# attackerOnly 0.8998000025749207
# mix 0.5
#
# imdb_attack_sst2_20231219-031627
# attackerOnly 0.9018399715423584
# mix 0.49082568287849426
#
# imdb_attack_yelp_polarity_20231219-034210
# attackerOnly 0.9083999991416931
# mix 0.5
#
# rotten_tomatoes_attack_imdb_20231219-041834
# attackerOnly 0.8761726021766663
# mix 0.893280029296875
#
# rotten_tomatoes_attack_sst2_20231219-042727
# attackerOnly 0.8883677124977112
# mix 0.4942660629749298
#
# sst2_attack_imdb_20231219-043840
# attackerOnly 0.9346330165863037
# mix 0.5
#
# sst2_attack_rotten_tomatoes_20231219-061427
# attackerOnly 0.9369266033172607
# mix 0.5

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_residualVictim_attackEvaluation_v4')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231127-193619
# Victim accuracy 0.5
#
# imdb_attack_sst2_20231127-193755
# Victim accuracy 0.5091742873191833
#
# imdb_attack_yelp_polarity_20231201-222005
# Victim accuracy 0.5
#
# rotten_tomatoes_attack_imdb_20231127-195940
# Victim accuracy 0.84552001953125
#
# rotten_tomatoes_attack_sst2_20231127-201710
# Victim accuracy 0.6915137767791748
#
# rotten_tomatoes_attack_yelp_polarity_20231202-002801
# Victim accuracy 0.7550263404846191
#
# sst2_attack_imdb_20231127-210025
# Victim accuracy 0.5
#
# sst2_attack_rotten_tomatoes_20231127-210528
# Victim accuracy 0.5
#
# sst2_attack_yelp_polarity_20231202-062823
# Victim accuracy 0.5001316070556641
#
# yelp_polarity_attack_imdb_20231202-083526
# Victim accuracy 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231202-084031
# Victim accuracy 0.5
#
# yelp_polarity_attack_sst2_20231202-084316
# Victim accuracy 0.5091742873191833

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_residualVictim_attackEvaluation')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231219-102243
# Victim accuracy 0.5
#
# imdb_attack_sst2_20231219-102331
# Victim accuracy 0.5091742873191833
#
# imdb_attack_yelp_polarity_20231219-103030
# Victim accuracy 0.5
#
# rotten_tomatoes_attack_imdb_20231219-112813
# Victim accuracy 0.8367999792098999
#
# rotten_tomatoes_attack_sst2_20231219-113051
# Victim accuracy 0.6582568883895874
#
# rotten_tomatoes_attack_yelp_polarity_20231219-113752
# Victim accuracy 0.7445263266563416
#
# sst2_attack_imdb_20231219-123542
# Victim accuracy 0.5000399947166443
#
# sst2_attack_rotten_tomatoes_20231219-123910
# Victim accuracy 0.5
#
# sst2_attack_yelp_polarity_20231219-123958
# Victim accuracy 0.5038684010505676
#
# yelp_polarity_attack_imdb_20231219-133742
# Victim accuracy 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231219-134018
# Victim accuracy 0.5
#
# yelp_polarity_attack_sst2_20231219-134105
# Victim accuracy 0.5091742873191833
