# %%
import os
import json
from dotenv import load_dotenv

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case1_sts_moeBaseline')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(result['eval_metric']['accuracy'])
    print()
# Out:
# imdb_with_rotten_tomatoes_20231119-195246
# 0.8758800029754639
#
# imdb_with_sst2_20231119-200842
# 0.8755599856376648
#
# imdb_with_yelp_polarity_20231119-202442
# 0.8872799873352051
#
# rotten_tomatoes_with_imdb_20231119-204040
# 0.8564727902412415
#
# rotten_tomatoes_with_sst2_20231119-204527
# 0.908067524433136
#
# rotten_tomatoes_with_yelp_polarity_20231119-205035
# 0.8583489656448364
#
# sst2_with_imdb_20231119-205655
# 0.9243119359016418
#
# sst2_with_rotten_tomatoes_20231119-214429
# 0.9300458431243896
#
# sst2_with_yelp_polarity_20231119-222019
# 0.911697268486023
#
# yelp_polarity_with_imdb_20231120-120742
# 0.9529210329055786
#
# yelp_polarity_with_rotten_tomatoes_20231120-161937
# 0.9528947472572327
#
# yelp_polarity_with_sst2_20231120-224642
# 0.949999988079071

# %%
dir_path = os.path.join(data_dir, 'case1_sentiment_moeBaseline')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(result['eval_accuracy'])
    print()
# Out:
# imdb_with_rotten_tomatoes_20231127-013437
# 0.9081599712371826
#
# imdb_with_sst2_20231127-015203
# 0.9059200286865234
#
# imdb_with_yelp_polarity_20231127-020339
# 0.916159987449646
#
# rotten_tomatoes_with_imdb_20231127-021253
# 0.8968105316162109
#
# rotten_tomatoes_with_sst2_20231127-021539
# 0.9146341681480408
#
# rotten_tomatoes_with_yelp_polarity_20231127-021914
# 0.9052532911300659
#
# sst2_with_imdb_20231127-022200
# 0.9369266033172607
#
# sst2_with_rotten_tomatoes_20231127-025022
# 0.9472476840019226
#
# sst2_with_yelp_polarity_20231127-033346
# 0.9323394298553467

# %%
dir_path = os.path.join(data_dir, 'case1_sts_moeBaseline_v1')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d


    result_path = os.path.join(dir_path, d, 'eval_results.json')

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(result['eval_metric']['accuracy'])
    print()
# Out:
# imdb_with_rotten_tomatoes_20231107-010821
# 0.8781200051307678
#
# imdb_with_sst2_20231107-014243
# 0.8801599740982056
#
# imdb_with_yelp_polarity_20231107-012414
# 0.8918399810791016
#
# rotten_tomatoes_with_imdb_20231107-020436
# 0.8602251410484314
#
# rotten_tomatoes_with_sst2_20231107-021547
# 0.9071294665336609
#
# rotten_tomatoes_with_yelp_polarity_20231107-021012
# 0.8667917251586914
#
# sst2_with_imdb_20231108-050201
# 0.9208715558052063
#
# sst2_with_rotten_tomatoes_20231108-052401
# 0.9300458431243896
#
# sst2_with_yelp_polarity_20231108-054558
# 0.9151375889778137
#
# yelp_polarity_with_imdb_20231107-104844
# 0.9537368416786194
#
# yelp_polarity_with_rotten_tomatoes_20231107-162141
# 0.9534473419189453
#
# yelp_polarity_with_sst2_20231107-215051
# 0.9518157839775085

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackTraining')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('attackerOnly', result['eval_attackerOnly']['dataset_2']['eval_accuracy'])
    print('mix', result['eval_mix']['dataset_1']['eval_accuracy_mixed'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231120-003041
# attackerOnly 0.5
# mix 0.5
#
# imdb_attack_sst2_20231120-020150
# attackerOnly 0.5
# mix 0.49082568287849426
#
# rotten_tomatoes_attack_imdb_20231120-033347
# attackerOnly 0.8611631989479065
# mix 0.8743199706077576
#
# rotten_tomatoes_attack_sst2_20231120-034045
# attackerOnly 0.8602251410484314
# mix 0.9277523159980774
#
# sst2_attack_imdb_20231120-034558
# attackerOnly 0.9243119359016418
# mix 0.5
#
# sst2_attack_rotten_tomatoes_20231120-045828
# attackerOnly 0.892201840877533
# mix 0.5

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackEvaluation_v2')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231114-213538
# Victim accuracy 0.5
#
# imdb_attack_sst2_20231114-213904
# Victim accuracy 0.5091742873191833
#
# imdb_attack_yelp_polarity_20231114-221548
# Victim accuracy 0.5539736747741699
#
# rotten_tomatoes_attack_imdb_20231115-011027
# Victim accuracy 0.871999979019165
#
# rotten_tomatoes_attack_sst2_20231115-013109
# Victim accuracy 0.9426605701446533
#
# rotten_tomatoes_attack_yelp_polarity_20231115-022352
# Victim accuracy 0.9480526447296143
#
# sst2_attack_imdb_20231115-093906
# Victim accuracy 0.5094000101089478
#
# sst2_attack_rotten_tomatoes_20231115-095148
# Victim accuracy 0.5694183707237244
#
# sst2_attack_yelp_polarity_20231115-095851
# Victim accuracy 0.9256842136383057
#
# yelp_polarity_attack_imdb_20231115-184831
# Victim accuracy 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231115-190114
# Victim accuracy 0.5
#
# yelp_polarity_attack_sst2_20231115-190429
# Victim accuracy 0.5091742873191833

# %%
dir_path = os.path.join(data_dir, 'case1_sts_residualVictim_attackEvaluation_v3')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_attack_rotten_tomatoes_20231118-115920
# Victim accuracy 0.4953095614910126
#
# imdb_attack_sst2_20231118-120237
# Victim accuracy 0.5091742873191833
#
# imdb_attack_yelp_polarity_20231118-123930
# Victim accuracy 0.5496842265129089
#
# rotten_tomatoes_attack_imdb_20231118-195645
# Victim accuracy 0.8720399737358093
#
# rotten_tomatoes_attack_sst2_20231118-201737
# Victim accuracy 0.9472476840019226
#
# rotten_tomatoes_attack_yelp_polarity_20231118-211021
# Victim accuracy 0.9486578702926636
#
# sst2_attack_imdb_20231119-042954
# Victim accuracy 0.5091999769210815
#
# sst2_attack_rotten_tomatoes_20231119-044237
# Victim accuracy 0.5
#
# sst2_attack_yelp_polarity_20231119-044551
# Victim accuracy 0.6297631859779358
#
# yelp_polarity_attack_imdb_20231119-123019
# Victim accuracy 0.5
#
# yelp_polarity_attack_rotten_tomatoes_20231119-124305
# Victim accuracy 0.5
#
# yelp_polarity_attack_sst2_20231119-124621
# Victim accuracy 0.5091742873191833

# %%
dir_path = os.path.join(data_dir, 'case1_sts_singleAdapter_training')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# imdb_20231119-202112
# Victim accuracy 0.8828399777412415
#
# rotten_tomatoes_20231119-203538
# Victim accuracy 0.8696060180664062
#
# sst2_20231119-203835
# Victim accuracy 0.9208715558052063
#
# yelp_polarity_20231119-210626
# Victim accuracy 0.957605242729187
