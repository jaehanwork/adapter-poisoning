# %%
import os
import json
from dotenv import load_dotenv
import numpy as np

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = os.getenv('DATA_IGN_DIR')

def dict_round(data):
    data_new = {}
    for k, v in data.items():
        if type(v) == float:
            v = round(v, 4)
        data_new[k] = v
    return data_new

# %%
dir_path = os.path.join(data_dir, 'case1_nli_singleAdapter_training')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# mnli_20231222-001403
# Victim accuracy 0.9103301763534546
#
# qnli_20231221-234939
# Victim accuracy 0.9271462559700012
#
# rte_20231221-234852
# Victim accuracy 0.6967508792877197
#
# scitail_20231222-001041
# Victim accuracy 0.9532208442687988

# %%
dir_path = os.path.join(data_dir, 'case1_nli_moeBaseline')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    if 'snli' in task_name:
        continue

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print(np.around(result['eval_accuracy'], 4))
    print()
# Out:
# mnli_with_qnli_20231219-013446
# 0.8809
#
# mnli_with_rte_20231219-004003
# 0.894
#
# mnli_with_scitail_20231219-021118
# 0.8929
#
# qnli_with_mnli_20231219-000357
# 0.9004
#
# qnli_with_rte_20231218-231928
# 0.9077
#
# qnli_with_scitail_20231218-234139
# 0.905
#
# rte_with_mnli_20231218-231839
# 0.7942
#
# rte_with_qnli_20231218-231702
# 0.7256
#
# rte_with_scitail_20231218-231750
# 0.6968
#
# scitail_with_mnli_20231219-003453
# 0.8919
#
# scitail_with_qnli_20231219-003121
# 0.9026
#
# scitail_with_rte_20231219-002613
# 0.9156

# %%
dir_path = os.path.join(data_dir, 'case1_nli_residualVictim_attackTraining_v1')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('attackerOnly', result['eval_attackerOnly']['dataset_2']['eval_accuracy'])
    print('mix', result['eval_mix']['dataset_1']['eval_accuracy_mixed'])
    print()
# Out:
# mnli_attack_qnli_20231220-170622
# attackerOnly 0.891699492931366
# mix 0.5053999423980713
#
# mnli_attack_rte_20231217-115721
# attackerOnly 0.8865495324134827
# mix 0.4729241728782654
#
# mnli_attack_scitail_20231220-222627
# attackerOnly 0.895183265209198
# mix 0.4961656332015991
#
# qnli_attack_mnli_20231215-195140
# attackerOnly 0.9097565412521362
# mix 0.5269615054130554
#
# qnli_attack_rte_20231215-165747
# attackerOnly 0.8835804462432861
# mix 0.4729241728782654
#
# qnli_attack_scitail_20231216-204959
# attackerOnly 0.9200073480606079
# mix 0.4961656332015991
#
# rte_attack_mnli_20231215-164800
# attackerOnly 0.7256317734718323
# mix 0.795365035533905
#
# rte_attack_qnli_20231215-163909
# attackerOnly 0.7075812220573425
# mix 0.5317590832710266
#
# rte_attack_scitail_20231216-204158
# attackerOnly 0.7328519821166992
# mix 0.7584356069564819
#
# scitail_attack_mnli_20231217-045403
# attackerOnly 0.9432515501976013
# mix 0.5269615054130554
#
# scitail_attack_qnli_20231217-030608
# attackerOnly 0.9455521702766418
# mix 0.5052168965339661
#
# scitail_attack_rte_20231217-012646
# attackerOnly 0.9409509301185608
# mix 0.5270758271217346

# %%
dir_path = os.path.join(data_dir, 'case1_nli_residualVictim_attackEvaluation')
for d in sorted(os.listdir(dir_path)):
    if d.startswith('.'):
        continue
    task_name = d

    result_path = os.path.join(dir_path, d, 'eval_results.json')

    if not os.path.exists(result_path):
        continue

    with open(result_path, 'r') as f:
        result = json.load(f)

    print(task_name)
    print('Victim accuracy', result['eval_accuracy'])
    print()
# Out:
# qnli_attack_rte_20240103-205538
# Victim accuracy 0.5198556184768677
#
# rte_attack_mnli_20240103-200023
# Victim accuracy 0.8815510272979736
#
# rte_attack_qnli_20240103-193239
# Victim accuracy 0.8649094104766846
#
# rte_attack_scitail_20240103-195511
# Victim accuracy 0.8711656332015991
